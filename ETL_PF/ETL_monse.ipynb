# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Unemployment, total (% of total labor force) (national estimate)**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
DesempleoTotal_df = pd.read_csv("Data/datasets_desempleo_total.csv")
DesempleoTotal_df.drop_duplicates(inplace=True)
DesempleoTotal_df = DesempleoTotal_df.reset_index(drop=True)
DesempleoTotal_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name     Indicator Code  1960
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS   NaN  \
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS   NaN
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2013  2014  2015  2016   2017  2018
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN    NaN   NaN  \
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN    NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN  7.91   NaN   NaN  11.18   NaN
#
#    2019   2020  2021  2022
# 0   NaN    NaN   NaN   NaN
# 1   NaN    NaN   NaN   NaN
# 2   NaN  11.71  5.58   NaN
#
# [3 rows x 67 columns]

# %%
DesempleoTotal_df = pd.melt(DesempleoTotal_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Unemployment percentage of total labor force")
DesempleoTotal_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  Year
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960  \
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 3  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
#
#    Unemployment percentage of total labor force
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# ...

# %%
DesempleoTotal_df['id'] = DesempleoTotal_df['Country Code'].str.cat(DesempleoTotal_df['Year'])
DesempleoTotal_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  Year
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960  \
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 3  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
#
#    Unemployment percentage of total labor force       id
# 0                                           NaN  ABW1960
# 1                                           NaN  AFE1960
# ...

# %%
# Eliminamos columnas que no serán usadas 
DesempleoTotal_df = DesempleoTotal_df.drop(columns=['Indicator Name','Indicator Code']).copy()

# %%
DesempleoTotal_df = DesempleoTotal_df.reset_index(drop=True)

# %%
DesempleoTotal_df.head(5)
# Out:
#                   Country Name Country Code  Year
# 0                        Aruba          ABW  1960  \
# 1  Africa Eastern and Southern          AFE  1960
# 2                  Afghanistan          AFG  1960
# 3   Africa Western and Central          AFW  1960
# 4                       Angola          AGO  1960
#
#    Unemployment percentage of total labor force       id
# 0                                           NaN  ABW1960
# 1                                           NaN  AFE1960
# 2                                           NaN  AFG1960
# 3                                           NaN  AFW1960
# 4                                           NaN  AGO1960

# %%
#DesempleoTotal_df.to_excel("Data_ETL/DesempleoTotal.xlsx",index=False)

# %% [markdown]
# ## **Unemployment, female (% of female labor force) (national estimate)**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
DesempleoMujeres_df = pd.read_csv("Data/datasets_desempleo_mujeres.csv", sep=',', skiprows=4)
DesempleoMujeres_df.drop_duplicates(inplace=True)
DesempleoMujeres_df = DesempleoMujeres_df.reset_index(drop=True)
DesempleoMujeres_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS  \
# 1  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 2  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
#
#    1960  1961  1962  1963  1964  1965  ...   2014  2015  2016   2017  2018
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN    NaN   NaN  \
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN    NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...  10.11   NaN   NaN  14.03   NaN
#
#    2019   2020  2021  2022  Unnamed: 67
# 0   NaN    NaN   NaN   NaN          NaN
# 1   NaN    NaN   NaN   NaN          NaN
# 2   NaN  16.77   5.5   NaN          NaN
#
# ...

# %%
DesempleoMujeres_df = pd.melt(DesempleoMujeres_df, id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Unemployment female percentage of labor force")
DesempleoMujeres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS  \
# 1  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 2  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 3  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 4  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
#
#    Year  Unemployment female percentage of labor force
# 0  1960                                            NaN
# 1  1960                                            NaN
# 2  1960                                            NaN
# ...

# %%
DesempleoMujeres_df['id'] = DesempleoMujeres_df['Country Code'].str.cat(DesempleoMujeres_df['Year'])
DesempleoMujeres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS  \
# 1  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 2  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 3  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 4  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
#
#    Year  Unemployment female percentage of labor force       id
# 0  1960                                            NaN  ABW1960
# 1  1960                                            NaN  AFE1960
# ...

# %%
# Eliminamos columnas que no serán usadas 
DesempleoMujeres_df = DesempleoMujeres_df.drop(columns=['Indicator Name','Indicator Code']).copy()
DesempleoMujeres_df = DesempleoMujeres_df.reset_index(drop=True)

# %%
DesempleoMujeres_df.head(5)
# Out:
#                   Country Name Country Code  Year
# 0                        Aruba          ABW  1960  \
# 1  Africa Eastern and Southern          AFE  1960
# 2                  Afghanistan          AFG  1960
# 3   Africa Western and Central          AFW  1960
# 4                       Angola          AGO  1960
#
#    Unemployment female percentage of labor force       id
# 0                                            NaN  ABW1960
# 1                                            NaN  AFE1960
# 2                                            NaN  AFG1960
# 3                                            NaN  AFW1960
# 4                                            NaN  AGO1960

# %%
#DesempleoMujeres_df.to_excel("Data_ETL/DesempleoMujeres.xlsx",index=False)

# %% [markdown]
# ## **Unemployment, male (% of male labor force) (national estimate)**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
DesempleoHombres_df = pd.read_csv("Data/datasets_desempleo_hombres.csv", sep=',', skiprows=4)
DesempleoHombres_df.drop_duplicates(inplace=True)
DesempleoHombres_df = DesempleoHombres_df.reset_index(drop=True)
DesempleoHombres_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS  \
# 1  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 2  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
#
#    1960  1961  1962  1963  1964  1965  ...  2014  2015  2016   2017  2018
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN    NaN   NaN  \
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN    NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...   7.2   NaN   NaN  10.37   NaN
#
#    2019   2020  2021  2022  Unnamed: 67
# 0   NaN    NaN   NaN   NaN          NaN
# 1   NaN    NaN   NaN   NaN          NaN
# 2   NaN  10.45   5.6   NaN          NaN
#
# ...

# %%
DesempleoHombres_df = pd.melt(DesempleoHombres_df, id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Unemployment male percentage of labor force")
DesempleoHombres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS  \
# 1  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 2  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 3  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 4  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
#
#    Year  Unemployment male percentage of labor force
# 0  1960                                          NaN
# 1  1960                                          NaN
# 2  1960                                          NaN
# ...

# %%
DesempleoHombres_df['id'] = DesempleoHombres_df['Country Code'].str.cat(DesempleoHombres_df['Year'])
DesempleoHombres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS  \
# 1  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 2  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 3  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 4  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
#
#    Year  Unemployment male percentage of labor force       id
# 0  1960                                          NaN  ABW1960
# 1  1960                                          NaN  AFE1960
# ...

# %%
# Eliminamos columnas que no serán usadas 
DesempleoHombres_df = DesempleoHombres_df.drop(columns=['Indicator Name','Indicator Code']).copy()

# %%
DesempleoHombres_df = DesempleoHombres_df.reset_index(drop=True)

# %%
DesempleoHombres_df.head(5)
# Out:
#                   Country Name Country Code  Year
# 0                        Aruba          ABW  1960  \
# 1  Africa Eastern and Southern          AFE  1960
# 2                  Afghanistan          AFG  1960
# 3   Africa Western and Central          AFW  1960
# 4                       Angola          AGO  1960
#
#    Unemployment male percentage of labor force       id
# 0                                          NaN  ABW1960
# 1                                          NaN  AFE1960
# 2                                          NaN  AFG1960
# 3                                          NaN  AFW1960
# 4                                          NaN  AGO1960

# %%
#DesempleoHombres_df.to_excel("Data_ETL/DesempleoHombres.xlsx",index=False)

# %% [markdown]
# ## **Distribution of Homicide Rates**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
DistribuciónTasaDeHomicidio_df = pd.read_csv("Data/datasets_distribution-of-homicide-rates.csv", sep=',')
DistribuciónTasaDeHomicidio_df.drop_duplicates(inplace=True)
DistribuciónTasaDeHomicidio_df = DistribuciónTasaDeHomicidio_df.reset_index(drop=True)
DistribuciónTasaDeHomicidio_df.head(3)
# Out:
#         Entity      Code  Year
# 0     Abkhazia  OWID_ABK  2015  \
# 1  Afghanistan       AFG  2009
# 2  Afghanistan       AFG  2010
#
#    Homicide rate per 100,000 population - Both sexes - All ages Continent
# 0                                                NaN                 Asia
# 1                                           4.071527                  NaN
# 2                                           3.487093                  NaN

# %%
# Cambiamos el tipo de dato de la columna 'Year' con el fin de hacer un concatenado 
DistribuciónTasaDeHomicidio_df['Year'] = DistribuciónTasaDeHomicidio_df['Year'].astype(str).copy()

# %%
#DistribuciónTasaDeHomicidio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4358 entries, 0 to 4357
# Data columns (total 5 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Entity                                                        4358 non-null   object
#  1   Code                                                          4182 non-null   object
#  2   Year                                                          4358 non-null   object
#  3   Homicide rate per 100,000 population - Both sexes - All ages  4204 non-null   float64
#  4   Continent                                                     285 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 170.4+ KB

# %%
# Agregamos un id de identificación
DistribuciónTasaDeHomicidio_df['id'] = DistribuciónTasaDeHomicidio_df['Code'].str.cat(DistribuciónTasaDeHomicidio_df['Year'])
DistribuciónTasaDeHomicidio_df.head(5)
# Out:
#         Entity      Code  Year
# 0     Abkhazia  OWID_ABK  2015  \
# 1  Afghanistan       AFG  2009
# 2  Afghanistan       AFG  2010
# 3  Afghanistan       AFG  2011
# 4  Afghanistan       AFG  2012
#
#    Homicide rate per 100,000 population - Both sexes - All ages Continent
# 0                                                NaN                 Asia  \
# 1                                           4.071527                  NaN
# 2                                           3.487093                  NaN
# 3                                           4.208668                  NaN
# 4                                           6.393913                  NaN
#
#              id
# 0  OWID_ABK2015
# 1       AFG2009
# 2       AFG2010
# 3       AFG2011
# 4       AFG2012

# %%
# Eliminamos columnas que no serán usadas 
DistribuciónTasaDeHomicidio_df = DistribuciónTasaDeHomicidio_df.drop(columns=['Continent']).copy()

# %%
DistribuciónTasaDeHomicidio_df = DistribuciónTasaDeHomicidio_df.reset_index(drop=True)
DistribuciónTasaDeHomicidio_df.head(5)
# Out:
#         Entity      Code  Year
# 0     Abkhazia  OWID_ABK  2015  \
# 1  Afghanistan       AFG  2009
# 2  Afghanistan       AFG  2010
# 3  Afghanistan       AFG  2011
# 4  Afghanistan       AFG  2012
#
#    Homicide rate per 100,000 population - Both sexes - All ages            id
# 0                                                NaN             OWID_ABK2015
# 1                                           4.071527                  AFG2009
# 2                                           3.487093                  AFG2010
# 3                                           4.208668                  AFG2011
# 4                                           6.393913                  AFG2012

# %%
#DistribuciónTasaDeHomicidio_df.to_excel("Data_ETL/DistribuciónTasaDeHomicidio.xlsx",index=False)

# %% [markdown]
# ## **datasets_human-rights-index-vdem**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
HumanRightsIndexVdem_df = pd.read_csv("Data/datasets_human-rights-index-vdem.csv", sep=',')
HumanRightsIndexVdem_df.drop_duplicates(inplace=True)
HumanRightsIndexVdem_df = HumanRightsIndexVdem_df.reset_index(drop=True)
HumanRightsIndexVdem_df.head(3)
# Out:
#         Entity Code  Year  civ_libs_vdem_owid  civ_libs_vdem_high_owid
# 0  Afghanistan  AFG  1789               0.125                    0.169  \
# 1  Afghanistan  AFG  1790               0.125                    0.169
# 2  Afghanistan  AFG  1791               0.125                    0.169
#
#    civ_libs_vdem_low_owid
# 0                   0.089
# 1                   0.089
# 2                   0.089

# %%
#HumanRightsIndexVdem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33377 entries, 0 to 33376
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Entity                   33377 non-null  object
#  1   Code                     31478 non-null  object
#  2   Year                     33377 non-null  int64
#  3   civ_libs_vdem_owid       33377 non-null  float64
#  4   civ_libs_vdem_high_owid  33377 non-null  float64
#  5   civ_libs_vdem_low_owid   33377 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.5+ MB

# %%
HumanRightsIndexVdem_df.to_excel("Data_ETL/HumanRightsIndexVdem.xlsx",index=False)

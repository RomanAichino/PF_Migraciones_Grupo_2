# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## **GDP per capita (current LCU)**

# %%
GDP_per_capita_LCU_df = pd.read_csv("Data/GDP per capita (current LCU).csv" ,sep=',', skiprows=4)
GDP_per_capita_LCU_df.drop_duplicates(inplace=True)
GDP_per_capita_LCU_df = GDP_per_capita_LCU_df.reset_index(drop=True)
GDP_per_capita_LCU_df = GDP_per_capita_LCU_df.drop('Unnamed: 67',axis=1).copy()
GDP_per_capita_LCU_df.head(3)
# Out:
#                   Country Name Country Code                Indicator Name
# 0                        Aruba          ABW  GDP per capita (current LCU)  \
# 1  Africa Eastern and Southern          AFE  GDP per capita (current LCU)
# 2                  Afghanistan          AFG  GDP per capita (current LCU)
#
#    Indicator Code         1960         1961         1962         1963
# 0  NY.GDP.PCAP.CN          NaN          NaN          NaN          NaN  \
# 1  NY.GDP.PCAP.CN          NaN          NaN          NaN          NaN
# 2  NY.GDP.PCAP.CN  2806.621853  2809.966656  2742.766372  3690.978191
#
#           1964         1965  ...          2013          2014          2015
# 0          NaN          NaN  ...  47463.063764  48226.731278  50874.281823  \
# 1          NaN          NaN  ...           NaN           NaN           NaN
# 2  3847.998303  4735.943807  ...  36105.457825  35959.834156  36226.066382
#
#            2016          2017          2018          2019          2020
# ...

# %%
GDP_per_capita_LCU_df = pd.melt(GDP_per_capita_LCU_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="GDP_per_capita_LCU")

# %%
GDP_per_capita_LCU_df = GDP_per_capita_LCU_df.drop(columns=['Indicator Name','Indicator Code']).copy()

# %%
GDP_per_capita_LCU_df['id'] = GDP_per_capita_LCU_df['Country Code'].str.cat(GDP_per_capita_LCU_df['Year'])
GDP_per_capita_LCU_df.head(5)
# Out:
#                   Country Name Country Code  Year  GDP_per_capita_LCU       id
# 0                        Aruba          ABW  1960                 NaN  ABW1960
# 1  Africa Eastern and Southern          AFE  1960                 NaN  AFE1960
# 2                  Afghanistan          AFG  1960         2806.621853  AFG1960
# 3   Africa Western and Central          AFW  1960                 NaN  AFW1960
# 4                       Angola          AGO  1960                 NaN  AGO1960

# %%
GDP_per_capita_LCU_df = GDP_per_capita_LCU_df[['id','Country Name','Country Code','Year','GDP_per_capita_LCU']]
GDP_per_capita_LCU_df.head(5)
# Out:
#         id                 Country Name Country Code  Year  GDP_per_capita_LCU
# 0  ABW1960                        Aruba          ABW  1960                 NaN
# 1  AFE1960  Africa Eastern and Southern          AFE  1960                 NaN
# 2  AFG1960                  Afghanistan          AFG  1960         2806.621853
# 3  AFW1960   Africa Western and Central          AFW  1960                 NaN
# 4  AGO1960                       Angola          AGO  1960                 NaN

# %%
#GDP_per_capita_LCU_df.to_excel("Data_ETL/GDP_per_capita_LCU.xlsx",index=False)

# %% [markdown]
# ## **Inflation, GDP deflator (annual %)**

# %%
Inflation_GDP_deflator_df = pd.read_csv("Data/Inflation, GDP deflator (annual %).csv", sep=',', skiprows=4)
Inflation_GDP_deflator_df.drop_duplicates(inplace=True)
Inflation_GDP_deflator_df = Inflation_GDP_deflator_df.reset_index(drop=True)
Inflation_GDP_deflator_df = Inflation_GDP_deflator_df.drop('Unnamed: 67',axis=1).copy()
Inflation_GDP_deflator_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                        Indicator Name     Indicator Code  1960      1961
# 0  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG   NaN       NaN  \
# 1  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG   NaN  1.933947
# 2  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG   NaN       NaN
#
#        1962      1963      1964      1965  ...      2013      2014      2015
# 0       NaN       NaN       NaN       NaN  ... -1.986755  2.335109  2.531592  \
# 1  0.599021  3.003934  3.905978  3.432336  ...  5.844111  5.743314  5.366462
# 2       NaN       NaN       NaN       NaN  ...  4.822785  0.566945  2.447563
#
#        2016      2017      2018      2019      2020      2021     2022
# 0 -1.389713 -1.753935  0.658318  2.996712 -5.588889  2.216017      NaN
# ...

# %%
Inflation_GDP_deflator_df = pd.melt(Inflation_GDP_deflator_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Inflation_GDP_deflator")
Inflation_GDP_deflator_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                        Indicator Name     Indicator Code  Year
# 0  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG  1960  \
# 1  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG  1960
# 2  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG  1960
# 3  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG  1960
# 4  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG  1960
#
#    Inflation_GDP_deflator
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
Inflation_GDP_deflator_df = Inflation_GDP_deflator_df.drop(columns=['Indicator Name','Indicator Code']).copy()

# %%
Inflation_GDP_deflator_df['id'] = Inflation_GDP_deflator_df['Country Code'].str.cat(Inflation_GDP_deflator_df['Year'])
Inflation_GDP_deflator_df.head(5)
# Out:
#                   Country Name Country Code  Year  Inflation_GDP_deflator
# 0                        Aruba          ABW  1960                     NaN  \
# 1  Africa Eastern and Southern          AFE  1960                     NaN
# 2                  Afghanistan          AFG  1960                     NaN
# 3   Africa Western and Central          AFW  1960                     NaN
# 4                       Angola          AGO  1960                     NaN
#
#         id
# 0  ABW1960
# 1  AFE1960
# 2  AFG1960
# 3  AFW1960
# 4  AGO1960

# %%
Inflation_GDP_deflator_df = Inflation_GDP_deflator_df[['id','Country Name','Country Code','Year','Inflation_GDP_deflator']]
Inflation_GDP_deflator_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    Inflation_GDP_deflator
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
#Inflation_GDP_deflator_df.to_excel("Data_ETL/Inflation_GDP_deflator.xlsx",index=False)

# %% [markdown]
# ## **PBI_constant_LCU**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
PBI_constant_LCU_df = pd.read_csv("Data/PBI_constant_LCU.csv", sep=',', skiprows=4)
PBI_constant_LCU_df.drop_duplicates(inplace=True)
PBI_constant_LCU_df = PBI_constant_LCU_df.reset_index(drop=True)
PBI_constant_LCU_df = PBI_constant_LCU_df.drop('Unnamed: 67',axis=1).copy()
PBI_constant_LCU_df.head(3)
# Out:
#                   Country Name Country Code      Indicator Name
# 0                        Aruba          ABW  GDP (constant LCU)  \
# 1  Africa Eastern and Southern          AFE  GDP (constant LCU)
# 2                  Afghanistan          AFG  GDP (constant LCU)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2013
# 0  NY.GDP.MKTP.KN   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.883000e+09  \
# 1  NY.GDP.MKTP.KN   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 2  NY.GDP.MKTP.KN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.147514e+12
#
#            2014          2015          2016          2017          2018
# 0  4.882000e+09  5.055000e+09  5.162000e+09  5.445000e+09  5.731290e+09  \
# 1           NaN           NaN           NaN           NaN           NaN
# 2  1.178778e+12  1.195886e+12  1.222917e+12  1.255288e+12  1.270216e+12
#
#            2019          2020          2021  2022
# 0  5.767686e+09  4.695525e+09  5.501864e+09   NaN
# ...

# %%
PBI_constant_LCU_df = pd.melt(PBI_constant_LCU_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="PBI_constant_LCU")
PBI_constant_LCU_df.head(5)
# Out:
#                   Country Name Country Code      Indicator Name
# 0                        Aruba          ABW  GDP (constant LCU)  \
# 1  Africa Eastern and Southern          AFE  GDP (constant LCU)
# 2                  Afghanistan          AFG  GDP (constant LCU)
# 3   Africa Western and Central          AFW  GDP (constant LCU)
# 4                       Angola          AGO  GDP (constant LCU)
#
#    Indicator Code  Year  PBI_constant_LCU
# 0  NY.GDP.MKTP.KN  1960               NaN
# 1  NY.GDP.MKTP.KN  1960               NaN
# 2  NY.GDP.MKTP.KN  1960               NaN
# 3  NY.GDP.MKTP.KN  1960               NaN
# 4  NY.GDP.MKTP.KN  1960               NaN

# %%
PBI_constant_LCU_df = PBI_constant_LCU_df.drop(columns=['Indicator Name','Indicator Code']).copy()
PBI_constant_LCU_df = PBI_constant_LCU_df.reset_index(drop=True)

# %%
PBI_constant_LCU_df['id'] = PBI_constant_LCU_df['Country Code'].str.cat(PBI_constant_LCU_df['Year'])
PBI_constant_LCU_df.head(5)
# Out:
#                   Country Name Country Code  Year  PBI_constant_LCU       id
# 0                        Aruba          ABW  1960               NaN  ABW1960
# 1  Africa Eastern and Southern          AFE  1960               NaN  AFE1960
# 2                  Afghanistan          AFG  1960               NaN  AFG1960
# 3   Africa Western and Central          AFW  1960               NaN  AFW1960
# 4                       Angola          AGO  1960               NaN  AGO1960

# %%
PBI_constant_LCU_df = PBI_constant_LCU_df[['id','Country Name','Country Code','Year','PBI_constant_LCU']]
PBI_constant_LCU_df.head(5)
# Out:
#         id                 Country Name Country Code  Year  PBI_constant_LCU
# 0  ABW1960                        Aruba          ABW  1960               NaN
# 1  AFE1960  Africa Eastern and Southern          AFE  1960               NaN
# 2  AFG1960                  Afghanistan          AFG  1960               NaN
# 3  AFW1960   Africa Western and Central          AFW  1960               NaN
# 4  AGO1960                       Angola          AGO  1960               NaN

# %%
#PBI_constant_LCU_df.to_excel("Data_ETL/PBI_constant_LCU.xlsx",index=False)

# %% [markdown]
# ## **PBI_per_capita_constant_LCU**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
PBI_per_capita_constant_LCU_df = pd.read_csv("Data/PBI_per_capita_constant_LCU.csv", sep=',', skiprows=4)
PBI_per_capita_constant_LCU_df.drop_duplicates(inplace=True)
PBI_per_capita_constant_LCU_df = PBI_per_capita_constant_LCU_df.reset_index(drop=True)
PBI_per_capita_constant_LCU_df = PBI_per_capita_constant_LCU_df.drop('Unnamed: 67',axis=1).copy()
PBI_per_capita_constant_LCU_df.head(3)
# Out:
#                   Country Name Country Code                 Indicator Name
# 0                        Aruba          ABW  GDP per capita (constant LCU)  \
# 1  Africa Eastern and Southern          AFE  GDP per capita (constant LCU)
# 2                  Afghanistan          AFG  GDP per capita (constant LCU)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2013
# 0  NY.GDP.PCAP.KN   NaN   NaN   NaN   NaN   NaN   NaN  ...  47463.063764  \
# 1  NY.GDP.PCAP.KN   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 2  NY.GDP.PCAP.KN   NaN   NaN   NaN   NaN   NaN   NaN  ...  36381.414679
#
#            2014          2015          2016          2017          2018
# 0  47126.281445  48485.952982  49220.969926  51641.233320  54088.165569  \
# 1           NaN           NaN           NaN           NaN           NaN
# 2  36030.405579  35429.988986  35307.471199  35217.933648  34623.251864
#
#            2019          2020          2021  2022
# ...

# %%
PBI_per_capita_constant_LCU_df = pd.melt(PBI_per_capita_constant_LCU_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="PBI_per_capita_constant_LCU")
PBI_per_capita_constant_LCU_df.head(5)
# Out:
#                   Country Name Country Code                 Indicator Name
# 0                        Aruba          ABW  GDP per capita (constant LCU)  \
# 1  Africa Eastern and Southern          AFE  GDP per capita (constant LCU)
# 2                  Afghanistan          AFG  GDP per capita (constant LCU)
# 3   Africa Western and Central          AFW  GDP per capita (constant LCU)
# 4                       Angola          AGO  GDP per capita (constant LCU)
#
#    Indicator Code  Year  PBI_per_capita_constant_LCU
# 0  NY.GDP.PCAP.KN  1960                          NaN
# 1  NY.GDP.PCAP.KN  1960                          NaN
# 2  NY.GDP.PCAP.KN  1960                          NaN
# 3  NY.GDP.PCAP.KN  1960                          NaN
# 4  NY.GDP.PCAP.KN  1960                          NaN

# %%
PBI_per_capita_constant_LCU_df = PBI_per_capita_constant_LCU_df.drop(columns=['Indicator Name','Indicator Code']).copy()
PBI_per_capita_constant_LCU_df = PBI_per_capita_constant_LCU_df.reset_index(drop=True)

# %%
PBI_per_capita_constant_LCU_df['id'] = PBI_per_capita_constant_LCU_df['Country Code'].str.cat(PBI_per_capita_constant_LCU_df['Year'])
PBI_per_capita_constant_LCU_df.head(5)
# Out:
#                   Country Name Country Code  Year
# 0                        Aruba          ABW  1960  \
# 1  Africa Eastern and Southern          AFE  1960
# 2                  Afghanistan          AFG  1960
# 3   Africa Western and Central          AFW  1960
# 4                       Angola          AGO  1960
#
#    PBI_per_capita_constant_LCU       id
# 0                          NaN  ABW1960
# 1                          NaN  AFE1960
# 2                          NaN  AFG1960
# 3                          NaN  AFW1960
# 4                          NaN  AGO1960

# %%
PBI_per_capita_constant_LCU_df = PBI_per_capita_constant_LCU_df[['id','Country Name','Country Code','Year','PBI_per_capita_constant_LCU']]
PBI_per_capita_constant_LCU_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    PBI_per_capita_constant_LCU
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %%
#PBI_per_capita_constant_LCU_df.to_excel("Data_ETL/PBI_per_capita_constant_LCU.xlsx",index=False)

# %% [markdown]
# ## **Personal remittances, received (% of GDP)**

# %%
Personal_remittances_received_df = pd.read_csv("Data/Personal remittances, received (percentage of GDP).csv", sep=',', skiprows=4)
Personal_remittances_received_df.drop_duplicates(inplace=True)
Personal_remittances_received_df = Personal_remittances_received_df.reset_index(drop=True)
Personal_remittances_received_df = Personal_remittances_received_df.drop('Unnamed: 67',axis=1).copy()
Personal_remittances_received_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                               Indicator Name        Indicator Code  1960
# 0  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS   NaN  \
# 1  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS   NaN
# 2  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...      2013      2014      2015      2016
# 0   NaN   NaN   NaN   NaN   NaN  ...  0.232335  0.267469  0.272810  1.765621  \
# 1   NaN   NaN   NaN   NaN   NaN  ...  0.963686  1.056650  1.189599  1.034992
# 2   NaN   NaN   NaN   NaN   NaN  ...  1.688179  1.232898  1.743285  3.483498
#
#        2017      2018      2019      2020      2021      2022
# 0  1.815559  1.126929  1.009013  1.340365  1.146686       NaN
# ...

# %%
Personal_remittances_received_df = pd.melt(Personal_remittances_received_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Personal_remittances_received")
Personal_remittances_received_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                               Indicator Name        Indicator Code  Year
# 0  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS  1960  \
# 1  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS  1960
# 2  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS  1960
# 3  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS  1960
# 4  Personal remittances, received (% of GDP)  BX.TRF.PWKR.DT.GD.ZS  1960
#
#    Personal_remittances_received
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %%
Personal_remittances_received_df = Personal_remittances_received_df.drop(columns=['Indicator Name','Indicator Code']).copy()
Personal_remittances_received_df = Personal_remittances_received_df.reset_index(drop=True)

# %%
Personal_remittances_received_df['id'] = Personal_remittances_received_df['Country Code'].str.cat(Personal_remittances_received_df['Year'])
Personal_remittances_received_df.head(5)
# Out:
#                   Country Name Country Code  Year
# 0                        Aruba          ABW  1960  \
# 1  Africa Eastern and Southern          AFE  1960
# 2                  Afghanistan          AFG  1960
# 3   Africa Western and Central          AFW  1960
# 4                       Angola          AGO  1960
#
#    Personal_remittances_received       id
# 0                            NaN  ABW1960
# 1                            NaN  AFE1960
# 2                            NaN  AFG1960
# 3                            NaN  AFW1960
# 4                            NaN  AGO1960

# %%
Personal_remittances_received_df = Personal_remittances_received_df[['id','Country Name','Country Code','Year','Personal_remittances_received']]
Personal_remittances_received_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    Personal_remittances_received
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %%
#Personal_remittances_received_df.to_excel("Data_ETL/Personal_remittances_received_df.xlsx",index=False)

# %% [markdown]
# ## **Population**

# %%
Population_Total_df = pd.read_csv("Data/Population_Total.csv", sep=',', skiprows=4)
Population_Total_df.drop_duplicates(inplace=True)
Population_Total_df = Population_Total_df.reset_index(drop=True)
Population_Total_df = Population_Total_df.drop('Unnamed: 67',axis=1).copy()
Population_Total_df.head(3)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL  \
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964
# 0      54608.0      55811.0      56682.0      57475.0      58178.0  \
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
#
#           1965  ...         2013         2014         2015         2016
# 0      58782.0  ...     102880.0     103594.0     104257.0     104874.0  \
# 1  149742351.0  ...  567892149.0  583651101.0  600008424.0  616377605.0
# 2    9565147.0  ...   31541209.0   32716210.0   33753499.0   34636207.0
#
#           2017         2018         2019         2020         2021
# ...

# %%
Population_Total_df = pd.melt(Population_Total_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Poblacion")
Population_Total_df.head(5)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL  \
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#    Year    Poblacion
# 0  1960      54608.0
# 1  1960  130692579.0
# 2  1960    8622466.0
# 3  1960   97256290.0
# 4  1960    5357195.0

# %%
Population_Total_df = Population_Total_df.drop(columns=['Indicator Name','Indicator Code']).copy()
Population_Total_df = Population_Total_df.reset_index(drop=True)

# %%
Population_Total_df['id'] = Population_Total_df['Country Code'].str.cat(Population_Total_df['Year'])
Population_Total_df.head(5)
# Out:
#                   Country Name Country Code  Year    Poblacion       id
# 0                        Aruba          ABW  1960      54608.0  ABW1960
# 1  Africa Eastern and Southern          AFE  1960  130692579.0  AFE1960
# 2                  Afghanistan          AFG  1960    8622466.0  AFG1960
# 3   Africa Western and Central          AFW  1960   97256290.0  AFW1960
# 4                       Angola          AGO  1960    5357195.0  AGO1960

# %%
Population_Total_df = Population_Total_df[['id','Country Name','Country Code','Year','Poblacion']]
Population_Total_df.head(5)
# Out:
#         id                 Country Name Country Code  Year    Poblacion
# 0  ABW1960                        Aruba          ABW  1960      54608.0
# 1  AFE1960  Africa Eastern and Southern          AFE  1960  130692579.0
# 2  AFG1960                  Afghanistan          AFG  1960    8622466.0
# 3  AFW1960   Africa Western and Central          AFW  1960   97256290.0
# 4  AGO1960                       Angola          AGO  1960    5357195.0

# %%
#Population_Total_df.to_excel("Data_ETL/Population_Total.xlsx",index=False)

# %% [markdown]
# ## **corruption-perception-index** (normlizar)

# %%
corruption_perception_index_df = pd.read_csv("Data/corruption-perception-index.csv", sep=',')
corruption_perception_index_df.drop_duplicates(inplace=True)
corruption_perception_index_df= corruption_perception_index_df.reset_index(drop=True)
corruption_perception_index_df.head(3)
# Out:
#         Entity Code  Year
# 0  Afghanistan  AFG  2012  \
# 1  Afghanistan  AFG  2013
# 2  Afghanistan  AFG  2014
#
#    Corruption Perception Index - Transparency International (2018)
# 0                                                  8
# 1                                                  8
# 2                                                 12

# %%
corruption_perception_index_df[corruption_perception_index_df['Entity']=='Kosovo']
# Out:
#      Entity      Code  Year
# 588  Kosovo  OWID_KOS  2012  \
# 589  Kosovo  OWID_KOS  2013
# 590  Kosovo  OWID_KOS  2014
# 591  Kosovo  OWID_KOS  2015
# 592  Kosovo  OWID_KOS  2016
# 593  Kosovo  OWID_KOS  2017
# 594  Kosovo  OWID_KOS  2018
#
#      Corruption Perception Index - Transparency International (2018)
# 588                                                 34
# 589                                                 33
# 590                                                 33
# 591                                                 33
# 592                                                 36
# 593                                                 39
# 594                                                 37

# %%
corruption_perception_index_df[]

# %%
corruption_perception_index_df.to_excel("Data_ETL/corruption_perception_index.xlsx",index=False)

# %% [markdown]
# ## **Unemployment, total (% of total labor force) (national estimate)**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
DesempleoTotal_df = pd.read_csv("Data/datasets_desempleo_total.csv")
DesempleoTotal_df.drop_duplicates(inplace=True)
DesempleoTotal_df = DesempleoTotal_df.reset_index(drop=True)
DesempleoTotal_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name     Indicator Code  1960
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS   NaN  \
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS   NaN
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2013  2014  2015  2016   2017  2018
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN    NaN   NaN  \
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN    NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN  7.91   NaN   NaN  11.18   NaN
#
#    2019   2020  2021  2022
# 0   NaN    NaN   NaN   NaN
# 1   NaN    NaN   NaN   NaN
# 2   NaN  11.71  5.58   NaN
#
# [3 rows x 67 columns]

# %%
DesempleoTotal_df = pd.melt(DesempleoTotal_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Unemployment percentage of total labor force")
DesempleoTotal_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  Year
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960  \
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 3  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
#
#    Unemployment percentage of total labor force
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# ...

# %%
DesempleoTotal_df['id'] = DesempleoTotal_df['Country Code'].str.cat(DesempleoTotal_df['Year'])
DesempleoTotal_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  Year
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960  \
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 3  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS  1960
#
#    Unemployment percentage of total labor force       id
# 0                                           NaN  ABW1960
# 1                                           NaN  AFE1960
# ...

# %%
# Eliminamos columnas que no serán usadas 
DesempleoTotal_df = DesempleoTotal_df.drop(columns=['Indicator Name','Indicator Code']).copy()
DesempleoTotal_df = DesempleoTotal_df.reset_index(drop=True)
DesempleoTotal_df.head(5)
# Out:
#                   Country Name Country Code  Year
# 0                        Aruba          ABW  1960  \
# 1  Africa Eastern and Southern          AFE  1960
# 2                  Afghanistan          AFG  1960
# 3   Africa Western and Central          AFW  1960
# 4                       Angola          AGO  1960
#
#    Unemployment percentage of total labor force       id
# 0                                           NaN  ABW1960
# 1                                           NaN  AFE1960
# 2                                           NaN  AFG1960
# 3                                           NaN  AFW1960
# 4                                           NaN  AGO1960

# %%
DesempleoTotal_df = DesempleoTotal_df[['id','Country Name','Country Code','Year','Unemployment percentage of total labor force']]
DesempleoTotal_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    Unemployment percentage of total labor force
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN

# %%
#DesempleoTotal_df.to_excel("Data_ETL/DesempleoTotal.xlsx",index=False)

# %% [markdown]
# ## **Unemployment, female (% of female labor force) (national estimate)**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
DesempleoMujeres_df = pd.read_csv("Data/datasets_desempleo_mujeres.csv", sep=',', skiprows=4)
DesempleoMujeres_df.drop_duplicates(inplace=True)
DesempleoMujeres_df = DesempleoMujeres_df.reset_index(drop=True)
DesempleoMujeres_df = DesempleoMujeres_df.drop('Unnamed: 67',axis=1).copy()
DesempleoMujeres_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS  \
# 1  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 2  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
#
#    1960  1961  1962  1963  1964  1965  ...  2013   2014  2015  2016   2017
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN    NaN   NaN   NaN    NaN  \
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN    NaN   NaN   NaN    NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN  10.11   NaN   NaN  14.03
#
#    2018  2019   2020  2021  2022
# 0   NaN   NaN    NaN   NaN   NaN
# 1   NaN   NaN    NaN   NaN   NaN
# 2   NaN   NaN  16.77   5.5   NaN
#
# [3 rows x 67 columns]

# %%
DesempleoMujeres_df = pd.melt(DesempleoMujeres_df, id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Unemployment female percentage of labor force")
DesempleoMujeres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS  \
# 1  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 2  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 3  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 4  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
#
#    Year  Unemployment female percentage of labor force
# 0  1960                                            NaN
# 1  1960                                            NaN
# 2  1960                                            NaN
# ...

# %%
DesempleoMujeres_df['id'] = DesempleoMujeres_df['Country Code'].str.cat(DesempleoMujeres_df['Year'])
DesempleoMujeres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS  \
# 1  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 2  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 3  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
# 4  Unemployment, female (% of female labor force)...  SL.UEM.TOTL.FE.NE.ZS
#
#    Year  Unemployment female percentage of labor force       id
# 0  1960                                            NaN  ABW1960
# 1  1960                                            NaN  AFE1960
# ...

# %%
# Eliminamos columnas que no serán usadas 
DesempleoMujeres_df = DesempleoMujeres_df.drop(columns=['Indicator Name','Indicator Code']).copy()
DesempleoMujeres_df = DesempleoMujeres_df.reset_index(drop=True)
DesempleoMujeres_df.head(5)
# Out:
#                   Country Name Country Code  Year
# 0                        Aruba          ABW  1960  \
# 1  Africa Eastern and Southern          AFE  1960
# 2                  Afghanistan          AFG  1960
# 3   Africa Western and Central          AFW  1960
# 4                       Angola          AGO  1960
#
#    Unemployment female percentage of labor force       id
# 0                                            NaN  ABW1960
# 1                                            NaN  AFE1960
# 2                                            NaN  AFG1960
# 3                                            NaN  AFW1960
# 4                                            NaN  AGO1960

# %%
DesempleoMujeres_df = DesempleoMujeres_df[['id','Country Name','Country Code','Year','Unemployment female percentage of labor force']]
DesempleoMujeres_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    Unemployment female percentage of labor force
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN

# %%
#DesempleoMujeres_df.to_excel("Data_ETL/DesempleoMujeres.xlsx",index=False)

# %% [markdown]
# ## **Unemployment, male (% of male labor force) (national estimate)**

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
DesempleoHombres_df = pd.read_csv("Data/datasets_desempleo_hombres.csv", sep=',', skiprows=4)
DesempleoHombres_df.drop_duplicates(inplace=True)
DesempleoHombres_df = DesempleoHombres_df.reset_index(drop=True)
DesempleoHombres_df = DesempleoHombres_df.drop('Unnamed: 67',axis=1).copy()
DesempleoHombres_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS  \
# 1  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 2  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
#
#    1960  1961  1962  1963  1964  1965  ...  2013  2014  2015  2016   2017
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN    NaN  \
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN    NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   7.2   NaN   NaN  10.37
#
#    2018  2019   2020  2021  2022
# 0   NaN   NaN    NaN   NaN   NaN
# 1   NaN   NaN    NaN   NaN   NaN
# 2   NaN   NaN  10.45   5.6   NaN
#
# [3 rows x 67 columns]

# %%
DesempleoHombres_df = pd.melt(DesempleoHombres_df, id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Unemployment male percentage of labor force")
DesempleoHombres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS  \
# 1  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 2  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 3  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 4  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
#
#    Year  Unemployment male percentage of labor force
# 0  1960                                          NaN
# 1  1960                                          NaN
# 2  1960                                          NaN
# ...

# %%
DesempleoHombres_df['id'] = DesempleoHombres_df['Country Code'].str.cat(DesempleoHombres_df['Year'])
DesempleoHombres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code
# 0  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS  \
# 1  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 2  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 3  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
# 4  Unemployment, male (% of male labor force) (na...  SL.UEM.TOTL.MA.NE.ZS
#
#    Year  Unemployment male percentage of labor force       id
# 0  1960                                          NaN  ABW1960
# 1  1960                                          NaN  AFE1960
# ...

# %%
# Eliminamos columnas que no serán usadas 
DesempleoHombres_df = DesempleoHombres_df.drop(columns=['Indicator Name','Indicator Code']).copy()
DesempleoHombres_df = DesempleoHombres_df.reset_index(drop=True)
DesempleoHombres_df.head(5)
# Out:
#                   Country Name Country Code  Year
# 0                        Aruba          ABW  1960  \
# 1  Africa Eastern and Southern          AFE  1960
# 2                  Afghanistan          AFG  1960
# 3   Africa Western and Central          AFW  1960
# 4                       Angola          AGO  1960
#
#    Unemployment male percentage of labor force       id
# 0                                          NaN  ABW1960
# 1                                          NaN  AFE1960
# 2                                          NaN  AFG1960
# 3                                          NaN  AFW1960
# 4                                          NaN  AGO1960

# %%
DesempleoHombres_df = DesempleoHombres_df[['id','Country Name','Country Code','Year','Unemployment male percentage of labor force']]
DesempleoHombres_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    Unemployment male percentage of labor force
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN

# %%
#DesempleoHombres_df.to_excel("Data_ETL/DesempleoHombres.xlsx",index=False)

# %% [markdown]
# ## **Distribution of Homicide Rates** (Normalizar)

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
DistribuciónTasaDeHomicidio_df = pd.read_csv("Data/datasets_distribution-of-homicide-rates.csv", sep=',')
DistribuciónTasaDeHomicidio_df.drop_duplicates(inplace=True)
DistribuciónTasaDeHomicidio_df = DistribuciónTasaDeHomicidio_df.reset_index(drop=True)
DistribuciónTasaDeHomicidio_df.head(3)
# Out:
#         Entity      Code  Year
# 0     Abkhazia  OWID_ABK  2015  \
# 1  Afghanistan       AFG  2009
# 2  Afghanistan       AFG  2010
#
#    Homicide rate per 100,000 population - Both sexes - All ages Continent
# 0                                                NaN                 Asia
# 1                                           4.071527                  NaN
# 2                                           3.487093                  NaN

# %%
# Cambiamos el tipo de dato de la columna 'Year' con el fin de hacer un concatenado 
DistribuciónTasaDeHomicidio_df['Year'] = DistribuciónTasaDeHomicidio_df['Year'].astype(str).copy()

# %%
#DistribuciónTasaDeHomicidio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4358 entries, 0 to 4357
# Data columns (total 5 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Entity                                                        4358 non-null   object
#  1   Code                                                          4182 non-null   object
#  2   Year                                                          4358 non-null   object
#  3   Homicide rate per 100,000 population - Both sexes - All ages  4204 non-null   float64
#  4   Continent                                                     285 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 170.4+ KB

# %%
# Agregamos un id de identificación
DistribuciónTasaDeHomicidio_df['id'] = DistribuciónTasaDeHomicidio_df['Code'].str.cat(DistribuciónTasaDeHomicidio_df['Year'])
DistribuciónTasaDeHomicidio_df.head(5)
# Out:
#         Entity      Code  Year
# 0     Abkhazia  OWID_ABK  2015  \
# 1  Afghanistan       AFG  2009
# 2  Afghanistan       AFG  2010
# 3  Afghanistan       AFG  2011
# 4  Afghanistan       AFG  2012
#
#    Homicide rate per 100,000 population - Both sexes - All ages Continent
# 0                                                NaN                 Asia  \
# 1                                           4.071527                  NaN
# 2                                           3.487093                  NaN
# 3                                           4.208668                  NaN
# 4                                           6.393913                  NaN
#
#              id
# 0  OWID_ABK2015
# 1       AFG2009
# 2       AFG2010
# 3       AFG2011
# 4       AFG2012

# %%
# Eliminamos columnas que no serán usadas 
DistribuciónTasaDeHomicidio_df = DistribuciónTasaDeHomicidio_df.drop(columns=['Continent']).copy()

# %%
DistribuciónTasaDeHomicidio_df = DistribuciónTasaDeHomicidio_df.reset_index(drop=True)
DistribuciónTasaDeHomicidio_df.head(5)
# Out:
#         Entity      Code  Year
# 0     Abkhazia  OWID_ABK  2015  \
# 1  Afghanistan       AFG  2009
# 2  Afghanistan       AFG  2010
# 3  Afghanistan       AFG  2011
# 4  Afghanistan       AFG  2012
#
#    Homicide rate per 100,000 population - Both sexes - All ages            id
# 0                                                NaN             OWID_ABK2015
# 1                                           4.071527                  AFG2009
# 2                                           3.487093                  AFG2010
# 3                                           4.208668                  AFG2011
# 4                                           6.393913                  AFG2012

# %%
DistribuciónTasaDeHomicidio_df.to_excel("Data_ETL/DistribuciónTasaDeHomicidio.xlsx",index=False)

# %% [markdown]
# ## **human-rights-index-vdem**(Normalizar)

# %%
# Cargamos, eliminamos duplicados y reseteamos el indice
HumanRightsIndexVdem_df = pd.read_csv("Data/datasets_human-rights-index-vdem.csv", sep=',')
HumanRightsIndexVdem_df.drop_duplicates(inplace=True)
HumanRightsIndexVdem_df = HumanRightsIndexVdem_df.reset_index(drop=True)
HumanRightsIndexVdem_df.head(3)
# Out:
#         Entity Code  Year  civ_libs_vdem_owid  civ_libs_vdem_high_owid
# 0  Afghanistan  AFG  1789               0.125                    0.169  \
# 1  Afghanistan  AFG  1790               0.125                    0.169
# 2  Afghanistan  AFG  1791               0.125                    0.169
#
#    civ_libs_vdem_low_owid
# 0                   0.089
# 1                   0.089
# 2                   0.089

# %%
#HumanRightsIndexVdem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33377 entries, 0 to 33376
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Entity                   33377 non-null  object
#  1   Code                     31478 non-null  object
#  2   Year                     33377 non-null  int64
#  3   civ_libs_vdem_owid       33377 non-null  float64
#  4   civ_libs_vdem_high_owid  33377 non-null  float64
#  5   civ_libs_vdem_low_owid   33377 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.5+ MB

# %%
HumanRightsIndexVdem_df.to_excel("Data_ETL/HumanRightsIndexVdem.xlsx",index=False)

# %% [markdown]
# ## **indicedesarrollohumano_argentina_1990_2021**

# %% [markdown]
# ## **Migración Neta**

# %%
NetMigration_df = pd.read_csv("Data/net_migration.csv", sep=',')
NetMigration_df.drop_duplicates(inplace=True)
NetMigration_df = NetMigration_df.reset_index(drop=True)
NetMigration_df = NetMigration_df.drop('Unnamed: 67',axis=1).copy()
NetMigration_df.head(3)
# Out:
#                   Country Name Country Code Indicator Name Indicator Code
# 0                        Aruba          ABW  Net migration    SM.POP.NETM  \
# 1  Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM
# 2                  Afghanistan          AFG  Net migration    SM.POP.NETM
#
#       1960    1961     1962     1963     1964     1965  ...     2013
# 0      0.0  -569.0   -609.0   -646.0   -684.0   -726.0  ...    134.0  \
# 1 -90849.0 -1348.0 -24259.0 -16266.0  37452.0  11041.0  ... -92842.0
# 2   2606.0  6109.0   7016.0   6681.0   7079.0  10695.0  ...  48076.0
#
#        2014      2015      2016      2017      2018      2019      2020
# 0      88.0     177.0     170.0     218.0     367.0     412.0       0.0  \
# 1 -199608.0  394925.0 -864708.0 -343075.0 -366105.0 -187410.0  -48955.0
# 2  255611.0 -281739.0  -90238.0  -47090.0  -47205.0   -8082.0  166821.0
#
#        2021  2022
# 0     501.0   NaN
# 1 -179444.0   NaN
# 2 -183672.0   NaN
#
# ...

# %%
NetMigration_df = pd.melt(NetMigration_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Migración Neta")
NetMigration_df.head(5)
# Out:
#                   Country Name Country Code Indicator Name Indicator Code
# 0                        Aruba          ABW  Net migration    SM.POP.NETM  \
# 1  Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM
# 2                  Afghanistan          AFG  Net migration    SM.POP.NETM
# 3   Africa Western and Central          AFW  Net migration    SM.POP.NETM
# 4                       Angola          AGO  Net migration    SM.POP.NETM
#
#    Year  Migración Neta
# 0  1960             0.0
# 1  1960        -90849.0
# 2  1960          2606.0
# 3  1960          -847.0
# 4  1960        -43749.0

# %%
NetMigration_df = NetMigration_df.drop(columns=['Indicator Name','Indicator Code']).copy()
NetMigration_df = NetMigration_df.reset_index(drop=True)

# %%
NetMigration_df['id'] = NetMigration_df['Country Code'].str.cat(NetMigration_df['Year'])
NetMigration_df.head(5)
# Out:
#                   Country Name Country Code  Year  Migración Neta       id
# 0                        Aruba          ABW  1960             0.0  ABW1960
# 1  Africa Eastern and Southern          AFE  1960        -90849.0  AFE1960
# 2                  Afghanistan          AFG  1960          2606.0  AFG1960
# 3   Africa Western and Central          AFW  1960          -847.0  AFW1960
# 4                       Angola          AGO  1960        -43749.0  AGO1960

# %%
NetMigration_df = NetMigration_df[['id','Country Name','Country Code','Year','Migración Neta']]
NetMigration_df.head(5)
# Out:
#         id                 Country Name Country Code  Year  Migración Neta
# 0  ABW1960                        Aruba          ABW  1960             0.0
# 1  AFE1960  Africa Eastern and Southern          AFE  1960        -90849.0
# 2  AFG1960                  Afghanistan          AFG  1960          2606.0
# 3  AFW1960   Africa Western and Central          AFW  1960          -847.0
# 4  AGO1960                       Angola          AGO  1960        -43749.0

# %%
#NetMigration_df.to_excel("Data_ETL/NetMigration.xlsx",index=False)

# %% [markdown]
# ## **Perception of Corruption by Institution**(Normalizar)

# %%
PerceptionOfCorruptionByInstitution_df = pd.read_csv("Data/perception-of-corruption-by-institution.csv", sep=',')
PerceptionOfCorruptionByInstitution_df.drop_duplicates(inplace=True)
PerceptionOfCorruptionByInstitution_df.reset_index(drop=True)
PerceptionOfCorruptionByInstitution_df.head(3)
# Out:
#         Entity Code  Year  Police  Legislature  Government officials
# 0  Afghanistan  AFG  2013      33         40.0                    43  \
# 1       Africa  NaN  2013      88         61.0                    67
# 2       Africa  NaN  2015      47         33.0                    38
#
#    Local government councillors  Prime Minister / President  Tax officials
# 0                           NaN                         NaN            NaN  \
# 1                           NaN                         NaN            NaN
# 2                          33.0                        31.0           37.0
#
#    Business executives  Judges and magistrates  Religious leaders
# 0                   35                      60               20.0  \
# 1                   48                      74               22.0
# 2                   42                      34               15.0
#
#    Traditional leaders
# 0                  NaN
# 1                  NaN
# 2                 21.0

# %%
#PerceptionOfCorruptionByInstitution_df[PerceptionOfCorruptionByInstitution_df['Entity'] == 'Palestine']
PerceptionOfCorruptionByInstitution_df[PerceptionOfCorruptionByInstitution_df['Entity'] == 'Taiwan']
# Out:
#      Entity Code  Year  Police  Legislature  Government officials
# 113  Taiwan  TWN  2013      56         75.0                    56  \
# 114  Taiwan  TWN  2017      18         49.0                    16
#
#      Local government councillors  Prime Minister / President  Tax officials
# 113                           NaN                         NaN            NaN  \
# 114                           NaN                         NaN            NaN
#
#      Business executives  Judges and magistrates  Religious leaders
# 113                   44                      57               33.0  \
# 114                   22                      24               23.0
#
#      Traditional leaders
# 113                  NaN
# 114                  NaN

# %%
PerceptionOfCorruptionByInstitution_df.to_excel("Data_ETL/perception-of-corruption-by-institution.xlsx", index=False)

# %% [markdown]
# ## **Salario de Trabajadores Hombres**

# %%
SalarioTrabajadoresHombres_df = pd.read_csv("Data/salarios_trabajadores_hombres.csv", sep=',', skiprows=4)
SalarioTrabajadoresHombres_df.drop_duplicates(inplace=True)
SalarioTrabajadoresHombres_df = SalarioTrabajadoresHombres_df.reset_index(drop=True)
SalarioTrabajadoresHombres_df = SalarioTrabajadoresHombres_df.drop('Unnamed: 67',axis=1).copy()
SalarioTrabajadoresHombres_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name     Indicator Code  1960
# 0  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS   NaN  \
# 1  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS   NaN
# 2  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN  \
# 1   NaN   NaN   NaN   NaN   NaN  ...  31.333423  31.874171  32.270438
# 2   NaN   NaN   NaN   NaN   NaN  ...  14.858920  16.118190  17.437260
#
#         2016       2017       2018       2019       2020       2021  2022
# 0        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# ...

# %%
SalarioTrabajadoresHombres_df = pd.melt(SalarioTrabajadoresHombres_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Salario Trabajador Hombre")
SalarioTrabajadoresHombres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  Year
# 0  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS  1960  \
# 1  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS  1960
# 2  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS  1960
# 3  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS  1960
# 4  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS  1960
#
#    Salario Trabajador Hombre
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
SalarioTrabajadoresHombres_df = SalarioTrabajadoresHombres_df.drop(columns=['Indicator Name','Indicator Code']).copy()
SalarioTrabajadoresHombres_df = SalarioTrabajadoresHombres_df.reset_index(drop=True)

# %%
SalarioTrabajadoresHombres_df['id'] = SalarioTrabajadoresHombres_df['Country Code'].str.cat(SalarioTrabajadoresHombres_df['Year'])
SalarioTrabajadoresHombres_df.head(5)
# Out:
#                   Country Name Country Code  Year  Salario Trabajador Hombre
# 0                        Aruba          ABW  1960                        NaN  \
# 1  Africa Eastern and Southern          AFE  1960                        NaN
# 2                  Afghanistan          AFG  1960                        NaN
# 3   Africa Western and Central          AFW  1960                        NaN
# 4                       Angola          AGO  1960                        NaN
#
#         id
# 0  ABW1960
# 1  AFE1960
# 2  AFG1960
# 3  AFW1960
# 4  AGO1960

# %%
SalarioTrabajadoresHombres_df = SalarioTrabajadoresHombres_df[['id','Country Name','Country Code','Year','Salario Trabajador Hombre']]
SalarioTrabajadoresHombres_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    Salario Trabajador Hombre
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
#SalarioTrabajadoresHombres_df.to_excel("Data_ETL/SalarioTrabajadoresHombres.xlsx",index=False)

# %% [markdown]
# ## **Salario de Trabajadores Mujeres**

# %%
SalarioTrabajadoresMujeres_df = pd.read_csv("Data/salarios_trabajadores_mujeres.csv", sep=',', skiprows=4)
SalarioTrabajadoresMujeres_df.drop_duplicates(inplace=True)
SalarioTrabajadoresMujeres_df = SalarioTrabajadoresMujeres_df.reset_index(drop=True)
SalarioTrabajadoresMujeres_df = SalarioTrabajadoresMujeres_df.drop('Unnamed: 67',axis=1).copy()
SalarioTrabajadoresMujeres_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name     Indicator Code  1960
# 0  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS   NaN  \
# 1  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS   NaN
# 2  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN  \
# 1   NaN   NaN   NaN   NaN   NaN  ...  19.415744  19.838548  20.133865
# 2   NaN   NaN   NaN   NaN   NaN  ...   3.169307   4.023759   5.163307
#
#         2016       2017       2018       2019       2020       2021  2022
# 0        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# ...

# %%
SalarioTrabajadoresMujeres_df = pd.melt(SalarioTrabajadoresMujeres_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Salario Trabajador Mujer")
SalarioTrabajadoresMujeres_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  Year
# 0  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS  1960  \
# 1  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS  1960
# 2  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS  1960
# 3  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS  1960
# 4  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS  1960
#
#    Salario Trabajador Mujer
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
SalarioTrabajadoresMujeres_df = SalarioTrabajadoresMujeres_df.drop(columns=['Indicator Name','Indicator Code']).copy()
SalarioTrabajadoresMujeres_df = SalarioTrabajadoresMujeres_df.reset_index(drop=True)

# %%
SalarioTrabajadoresMujeres_df['id'] = SalarioTrabajadoresMujeres_df['Country Code'].str.cat(SalarioTrabajadoresMujeres_df['Year'])
SalarioTrabajadoresMujeres_df.head(5)
# Out:
#                   Country Name Country Code  Year  Salario Trabajador Mujer
# 0                        Aruba          ABW  1960                       NaN  \
# 1  Africa Eastern and Southern          AFE  1960                       NaN
# 2                  Afghanistan          AFG  1960                       NaN
# 3   Africa Western and Central          AFW  1960                       NaN
# 4                       Angola          AGO  1960                       NaN
#
#         id
# 0  ABW1960
# 1  AFE1960
# 2  AFG1960
# 3  AFW1960
# 4  AGO1960

# %%
SalarioTrabajadoresMujeres_df = SalarioTrabajadoresMujeres_df[['id','Country Name','Country Code','Year','Salario Trabajador Mujer']]
SalarioTrabajadoresMujeres_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    Salario Trabajador Mujer
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
#SalarioTrabajadoresMujeres_df.to_excel("Data_ETL/SalarioTrabajadoresMujeres.xlsx",index=False)

# %% [markdown]
# ## **Salario de Trabajadores Total**

# %%
SalarioTrabajadoresTotal_df = pd.read_csv("Data/salarios_trabajadores_total.csv", sep=',', skiprows=4)
SalarioTrabajadoresTotal_df.drop_duplicates(inplace=True)
SalarioTrabajadoresTotal_df = SalarioTrabajadoresTotal_df.reset_index(drop=True)
SalarioTrabajadoresTotal_df = SalarioTrabajadoresTotal_df.drop('Unnamed: 67',axis=1).copy()
SalarioTrabajadoresTotal_df.head(3)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name  Indicator Code  1960
# 0  Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS   NaN  \
# 1  Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS   NaN
# 2  Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN  \
# 1   NaN   NaN   NaN   NaN   NaN  ...  25.726854  26.213394  26.564049
# 2   NaN   NaN   NaN   NaN   NaN  ...  12.901040  13.982730  15.153190
#
#         2016       2017       2018       2019       2020       2021  2022
# 0        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# ...

# %%
SalarioTrabajadoresTotal_df = pd.melt(SalarioTrabajadoresTotal_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Salario Trabajador Total")
SalarioTrabajadoresTotal_df.head(5)
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  Year
# 0  Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS  1960  \
# 1  Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS  1960
# 2  Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS  1960
# 3  Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS  1960
# 4  Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS  1960
#
#    Salario Trabajador Total
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
SalarioTrabajadoresTotal_df = SalarioTrabajadoresTotal_df.drop(columns=['Indicator Name','Indicator Code']).copy()
SalarioTrabajadoresTotal_df = SalarioTrabajadoresTotal_df.reset_index(drop=True)

# %%
SalarioTrabajadoresTotal_df['id'] = SalarioTrabajadoresTotal_df['Country Code'].str.cat(SalarioTrabajadoresTotal_df['Year'])
SalarioTrabajadoresTotal_df.head(5)
# Out:
#                   Country Name Country Code  Year  Salario Trabajador Total
# 0                        Aruba          ABW  1960                       NaN  \
# 1  Africa Eastern and Southern          AFE  1960                       NaN
# 2                  Afghanistan          AFG  1960                       NaN
# 3   Africa Western and Central          AFW  1960                       NaN
# 4                       Angola          AGO  1960                       NaN
#
#         id
# 0  ABW1960
# 1  AFE1960
# 2  AFG1960
# 3  AFW1960
# 4  AGO1960

# %%
SalarioTrabajadoresTotal_df = SalarioTrabajadoresTotal_df[['id','Country Name','Country Code','Year','Salario Trabajador Total']]
SalarioTrabajadoresTotal_df.head(5)
# Out:
#         id                 Country Name Country Code  Year
# 0  ABW1960                        Aruba          ABW  1960  \
# 1  AFE1960  Africa Eastern and Southern          AFE  1960
# 2  AFG1960                  Afghanistan          AFG  1960
# 3  AFW1960   Africa Western and Central          AFW  1960
# 4  AGO1960                       Angola          AGO  1960
#
#    Salario Trabajador Total
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
#SalarioTrabajadoresTotal_df.to_excel("Data_ETL/salarios_trabajadores_total.xlsx",index=False)

# %% [markdown]
# ## **Skill Migration Public** (Normalizar)

# %%
SkillMigrationPublic_df = pd.read_csv("Data/skill_migration_public.csv", sep=',')
SkillMigrationPublic_df.drop_duplicates(inplace=True)
SkillMigrationPublic_df = SkillMigrationPublic_df.reset_index(drop=True)
SkillMigrationPublic_df.head(3)
# Out:
#   country_code country_name   wb_income   wb_region  skill_group_id
# 0           af  Afghanistan  Low income  South Asia          2549.0  \
# 1           af  Afghanistan  Low income  South Asia          2608.0
# 2           af  Afghanistan  Low income  South Asia          3806.0
#
#           skill_group_category        skill_group_name  net_per_10K_2015
# 0                  Tech Skills  Information Management           -791.59  \
# 1              Business Skills  Operational Efficiency          -1610.25
# 2  Specialized Industry Skills       National Security          -1731.45
#
#    net_per_10K_2016  net_per_10K_2017  ...  Unnamed: 19  Unnamed: 20
# 0           -705.88           -550.04  ...          NaN          NaN  \
# 1           -933.55           -776.06  ...          NaN          NaN
# 2           -769.68           -756.59  ...          NaN          NaN
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# ...

# %%
SkillMigrationPublic_df.to_excel("Data_ETL/SkillMigrationPublic.xlsx",index=False)

# %% [markdown]
# ## **Taza Pobreza**

# %%
TasaPobreza_df = pd.read_csv("Data/tasa_pobreza.csv", sep=',', skiprows=4)
TasaPobreza_df.drop_duplicates(inplace=True)
TasaPobreza_df = TasaPobreza_df.reset_index(drop=True)
TasaPobreza_df = TasaPobreza_df.drop('Unnamed: 67',axis=1).copy()
TasaPobreza_df.head(3)
# Out:
#   Country Name Country Code
# 0        Aruba          ABW  \
# 1        Aruba          ABW
# 2        Aruba          ABW
#
#                                       Indicator Name  Indicator Code  1960
# 0  Annualized average growth rate in per capita r...  SI.SPR.PCAP.ZG   NaN  \
# 1  Survey mean consumption or income per capita, ...     SI.SPR.PCAP   NaN
# 2  Annualized average growth rate in per capita r...  SI.SPR.PC40.ZG   NaN
#
#    1961  1962  1963  1964  1965  ...  2013  2014  2015  2016  2017  2018
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN  \
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2019  2020  2021  2022
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
#
# [3 rows x 67 columns]

# %%
TasaPobreza_df = pd.melt(TasaPobreza_df,id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], var_name="Year", value_name="Tasa de Pobreza")
TasaPobreza_df.head(5)
# Out:
#   Country Name Country Code
# 0        Aruba          ABW  \
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name  Indicator Code  Year
# 0  Annualized average growth rate in per capita r...  SI.SPR.PCAP.ZG  1960  \
# 1  Survey mean consumption or income per capita, ...     SI.SPR.PCAP  1960
# 2  Annualized average growth rate in per capita r...  SI.SPR.PC40.ZG  1960
# 3  Survey mean consumption or income per capita, ...     SI.SPR.PC40  1960
# 4          Poverty gap at $6.85 a day (2017 PPP) (%)  SI.POV.UMIC.GP  1960
#
#    Tasa de Pobreza
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
TasaPobreza_df = TasaPobreza_df.drop(columns=['Indicator Name','Indicator Code']).copy()
TasaPobreza_df = TasaPobreza_df.reset_index(drop=True)

# %%
TasaPobreza_df['id'] = TasaPobreza_df['Country Code'].str.cat(TasaPobreza_df['Year'])
TasaPobreza_df.head(5)
# Out:
#   Country Name Country Code  Year  Tasa de Pobreza       id
# 0        Aruba          ABW  1960              NaN  ABW1960
# 1        Aruba          ABW  1960              NaN  ABW1960
# 2        Aruba          ABW  1960              NaN  ABW1960
# 3        Aruba          ABW  1960              NaN  ABW1960
# 4        Aruba          ABW  1960              NaN  ABW1960

# %%
TasaPobreza_df = TasaPobreza_df[['id','Country Name','Country Code','Year','Tasa de Pobreza']]
TasaPobreza_df.head(5)
# Out:
#         id Country Name Country Code  Year  Tasa de Pobreza
# 0  ABW1960        Aruba          ABW  1960              NaN
# 1  ABW1960        Aruba          ABW  1960              NaN
# 2  ABW1960        Aruba          ABW  1960              NaN
# 3  ABW1960        Aruba          ABW  1960              NaN
# 4  ABW1960        Aruba          ABW  1960              NaN

# %%
#TasaPobreza_df.to_excel("Data_ETL/TasaPobreza.xlsx",index=False)
